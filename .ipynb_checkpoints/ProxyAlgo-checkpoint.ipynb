# %%
#general imports
import numpy as np
import pandas as pd


import unicodedata
import string
import re

#sklearn imports
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn import preprocessing
from sklearn.model_selection import train_test_split


#nltk imports
import nltk
from nltk.util import ngrams
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem.snowball import  SnowballStemmer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import stopwords
import re
import string
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
from nltk.corpus import stopwords

stop = stopwords.words('english')
stop_words_ = set(stopwords.words('english'))
wn = WordNetLemmatizer()

np.set_printoptions(linewidth=100)

sw = stopwords.words('english')
pt = string.punctuation
stemmer = SnowballStemmer('english')

import pandas as pd
from rake_nltk import Rake
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import pandas as pd
import numpy as np
import re

from similarity.jarowinkler import JaroWinkler
from similarity.cosine import Cosine
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno 8] nodename nor
# [nltk_data]     servname provided, or not known>
# [nltk_data] Error loading stopwords: <urlopen error [Errno 8] nodename
# [nltk_data]     nor servname provided, or not known>
# [nltk_data] Error loading wordnet: <urlopen error [Errno 8] nodename
# [nltk_data]     nor servname provided, or not known>
# [nltk_data] Error loading averaged_perceptron_tagger: <urlopen error
# [nltk_data]     [Errno 8] nodename nor servname provided, or not
# [nltk_data]     known>

# %%
#clean inital dataframe input
testingdf = pd.read_csv('data/training.csv')
testingdf.set_index(['Product'], inplace=True)
testingdf.dropna(inplace=True)
testingdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4615 entries, 1 Day Acuvue Brand Contact Lenses to the Balm BalmShelter Tinted Moisturizer SPF 18
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Category     4615 non-null   object
#  1   UserRating   4615 non-null   float64
#  2   ReviewText2  4615 non-null   object
#  3   Tags2        4615 non-null   object
#  4   UserInput    4615 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 216.3+ KB

# %%
testingdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4615 entries, 1 Day Acuvue Brand Contact Lenses to the Balm BalmShelter Tinted Moisturizer SPF 18
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Category     4615 non-null   object
#  1   UserRating   4615 non-null   float64
#  2   ReviewText2  4615 non-null   object
#  3   Tags2        4615 non-null   object
#  4   UserInput    4615 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 216.3+ KB

# %%
def select_category(df, category):
    return df.loc[df['Category'] == category]

# %%
#test our function for restricted category - use as input to subsequent functs
select_category(testingdf, 'More Moisturizer')
# Out:
#                                                             Category  \
# Product
# 100% Pure Aqua Boost Hydrating Mask                 More Moisturizer
# 100% Pure Argan Oil Hydration Facial Moisturize...  More Moisturizer
# 3LAB "M" Cream                                      More Moisturizer
# 3LAB Shine Stop Moisturizer                         More Moisturizer
# 40 Carrots Carrot and C Vitamin Serum               More Moisturizer
# ...                                                              ...
# iS Clinical Firming Complex                         More Moisturizer
# iS Clinical Youth Complex                           More Moisturizer
# j.Sabatelli Cosmetics j.Sabatelli Brazil Firmin...  More Moisturizer
# mark For Goodness Face Antioxidant Skin Moistur...  More Moisturizer
# the Balm BalmShelter Tinted Moisturizer SPF 18      More Moisturizer
#
#                                                     UserRating  \
# Product
# 100% Pure Aqua Boost Hydrating Mask                  10.000000
# 100% Pure Argan Oil Hydration Facial Moisturize...    8.000000
# 3LAB "M" Cream                                        9.333333
# 3LAB Shine Stop Moisturizer                           2.000000
# 40 Carrots Carrot and C Vitamin Serum                 6.000000
# ...                                                        ...
# iS Clinical Firming Complex                           8.000000
# iS Clinical Youth Complex                             4.000000
# j.Sabatelli Cosmetics j.Sabatelli Brazil Firmin...   10.000000
# mark For Goodness Face Antioxidant Skin Moistur...    9.500000
# the Balm BalmShelter Tinted Moisturizer SPF 18        9.888889
#
#                                                                                           ReviewText2  \
# Product
# 100% Pure Aqua Boost Hydrating Mask                 kind face mask cream freak test lot different ...
# 100% Pure Argan Oil Hydration Facial Moisturize...  pure argan oil hydration facial moisturizer sp...
# 3LAB "M" Cream                                      cream luxurious really make improvement skin e...
# 3LAB Shine Stop Moisturizer                         think would help oily skin expensive didnt say...
# 40 Carrots Carrot and C Vitamin Serum               love carrots serum leave skin feel silky prote...
# ...                                                                                               ...
# iS Clinical Firming Complex                         clinical products recommend beauty mag editor ...
# iS Clinical Youth Complex                           use power rich dermalogica couple years want t...
# j.Sabatelli Cosmetics j.Sabatelli Brazil Firmin...  never really healthy glow skin use along sabat...
# mark For Goodness Face Antioxidant Skin Moistur...  good moisturizer make skin really soft plus sp...
# the Balm BalmShelter Tinted Moisturizer SPF 18      tint moisturizers general arent enough coverag...
#
#                                                                                                 Tags2  \
# Product
# 100% Pure Aqua Boost Hydrating Mask                       hydrate different winter smooth since range
# 100% Pure Argan Oil Hydration Facial Moisturize...  moisturizer watery thick thailand temperature ...
# 3LAB "M" Cream                                            really wasnt notice leave cream without ive
# 3LAB Shine Stop Moisturizer                                  would without waste think products money
# 40 Carrots Carrot and C Vitamin Serum                           start serum product years weeks tight
# ...                                                                                               ...
# iS Clinical Firming Complex                             products think serums recommend potion please
# iS Clinical Youth Complex                                     power spend youth years wouldnt without
# j.Sabatelli Cosmetics j.Sabatelli Brazil Firmin...    sabatelli really radiant products never healthy
# mark For Goodness Face Antioxidant Skin Moistur...   moisturizer thing really package great dispenser
# the Balm BalmShelter Tinted Moisturizer SPF 18       product moisturizer coverage review really leave
#
#                                                     UserInput
# Product
# 100% Pure Aqua Boost Hydrating Mask                         0
# 100% Pure Argan Oil Hydration Facial Moisturize...          0
# 3LAB "M" Cream                                              0
# 3LAB Shine Stop Moisturizer                                 0
# 40 Carrots Carrot and C Vitamin Serum                       0
# ...                                                       ...
# iS Clinical Firming Complex                                 0
# iS Clinical Youth Complex                                   0
# j.Sabatelli Cosmetics j.Sabatelli Brazil Firmin...          0
# mark For Goodness Face Antioxidant Skin Moistur...          0
# the Balm BalmShelter Tinted Moisturizer SPF 18              0
#
# [1276 rows x 5 columns]

# %%
#input text function

def user_input(df, tags):
    """INPUT: df > resulting dataframe from select category function
        tags > user enters in a string of words 6 total from a
        from a dropdown list"""
    """OUTPUT: dataframe with column of input tags """
    
    df.loc[df.UserInput < 1, 'UserInput'] = str(tags)
    df['UserInput'] = df['UserInput'].astype("string")
    df['Tags2'] = df['Tags2'].astype("string")
    
    return df

# %%
user_input(select_category(testingdf, 'More Moisturizer'), 'power, healthy, coverage, radiant, great, youth')
# Out:
# /Users/jessicapmouras/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /Users/jessicapmouras/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/jessicapmouras/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#                                                             Category  \
# Product
# 100% Pure Aqua Boost Hydrating Mask                 More Moisturizer
# 100% Pure Argan Oil Hydration Facial Moisturize...  More Moisturizer
# 3LAB "M" Cream                                      More Moisturizer
# 3LAB Shine Stop Moisturizer                         More Moisturizer
# 40 Carrots Carrot and C Vitamin Serum               More Moisturizer
# ...                                                              ...
# iS Clinical Firming Complex                         More Moisturizer
# iS Clinical Youth Complex                           More Moisturizer
# j.Sabatelli Cosmetics j.Sabatelli Brazil Firmin...  More Moisturizer
# mark For Goodness Face Antioxidant Skin Moistur...  More Moisturizer
# the Balm BalmShelter Tinted Moisturizer SPF 18      More Moisturizer
#
#                                                     UserRating  \
# Product
# 100% Pure Aqua Boost Hydrating Mask                  10.000000
# 100% Pure Argan Oil Hydration Facial Moisturize...    8.000000
# 3LAB "M" Cream                                        9.333333
# 3LAB Shine Stop Moisturizer                           2.000000
# 40 Carrots Carrot and C Vitamin Serum                 6.000000
# ...                                                        ...
# iS Clinical Firming Complex                           8.000000
# iS Clinical Youth Complex                             4.000000
# j.Sabatelli Cosmetics j.Sabatelli Brazil Firmin...   10.000000
# mark For Goodness Face Antioxidant Skin Moistur...    9.500000
# the Balm BalmShelter Tinted Moisturizer SPF 18        9.888889
#
#                                                                                           ReviewText2  \
# Product
# 100% Pure Aqua Boost Hydrating Mask                 kind face mask cream freak test lot different ...
# 100% Pure Argan Oil Hydration Facial Moisturize...  pure argan oil hydration facial moisturizer sp...
# 3LAB "M" Cream                                      cream luxurious really make improvement skin e...
# 3LAB Shine Stop Moisturizer                         think would help oily skin expensive didnt say...
# 40 Carrots Carrot and C Vitamin Serum               love carrots serum leave skin feel silky prote...
# ...                                                                                               ...
# iS Clinical Firming Complex                         clinical products recommend beauty mag editor ...
# iS Clinical Youth Complex                           use power rich dermalogica couple years want t...
# j.Sabatelli Cosmetics j.Sabatelli Brazil Firmin...  never really healthy glow skin use along sabat...
# mark For Goodness Face Antioxidant Skin Moistur...  good moisturizer make skin really soft plus sp...
# the Balm BalmShelter Tinted Moisturizer SPF 18      tint moisturizers general arent enough coverag...
#
#                                                                                                 Tags2  \
# Product
# 100% Pure Aqua Boost Hydrating Mask                       hydrate different winter smooth since range
# 100% Pure Argan Oil Hydration Facial Moisturize...  moisturizer watery thick thailand temperature ...
# 3LAB "M" Cream                                            really wasnt notice leave cream without ive
# 3LAB Shine Stop Moisturizer                                  would without waste think products money
# 40 Carrots Carrot and C Vitamin Serum                           start serum product years weeks tight
# ...                                                                                               ...
# iS Clinical Firming Complex                             products think serums recommend potion please
# iS Clinical Youth Complex                                     power spend youth years wouldnt without
# j.Sabatelli Cosmetics j.Sabatelli Brazil Firmin...    sabatelli really radiant products never healthy
# mark For Goodness Face Antioxidant Skin Moistur...   moisturizer thing really package great dispenser
# the Balm BalmShelter Tinted Moisturizer SPF 18       product moisturizer coverage review really leave
#
#                                                                                           UserInput
# Product
# 100% Pure Aqua Boost Hydrating Mask                 power, healthy, coverage, radiant, great, youth
# 100% Pure Argan Oil Hydration Facial Moisturize...  power, healthy, coverage, radiant, great, youth
# 3LAB "M" Cream                                      power, healthy, coverage, radiant, great, youth
# 3LAB Shine Stop Moisturizer                         power, healthy, coverage, radiant, great, youth
# 40 Carrots Carrot and C Vitamin Serum               power, healthy, coverage, radiant, great, youth
# ...                                                                                             ...
# iS Clinical Firming Complex                         power, healthy, coverage, radiant, great, youth
# iS Clinical Youth Complex                           power, healthy, coverage, radiant, great, youth
# j.Sabatelli Cosmetics j.Sabatelli Brazil Firmin...  power, healthy, coverage, radiant, great, youth
# mark For Goodness Face Antioxidant Skin Moistur...  power, healthy, coverage, radiant, great, youth
# the Balm BalmShelter Tinted Moisturizer SPF 18      power, healthy, coverage, radiant, great, youth
#
# [1276 rows x 5 columns]

# %%
user_input(select_category(testingdf, 'More Moisturizer'), 'power, healthy, coverage, radiant, great, youth')
# Out:
# /Users/jessicapmouras/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /Users/jessicapmouras/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/jessicapmouras/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#                                                             Category  \
# Product
# 100% Pure Aqua Boost Hydrating Mask                 More Moisturizer
# 100% Pure Argan Oil Hydration Facial Moisturize...  More Moisturizer
# 3LAB "M" Cream                                      More Moisturizer
# 3LAB Shine Stop Moisturizer                         More Moisturizer
# 40 Carrots Carrot and C Vitamin Serum               More Moisturizer
# ...                                                              ...
# iS Clinical Firming Complex                         More Moisturizer
# iS Clinical Youth Complex                           More Moisturizer
# j.Sabatelli Cosmetics j.Sabatelli Brazil Firmin...  More Moisturizer
# mark For Goodness Face Antioxidant Skin Moistur...  More Moisturizer
# the Balm BalmShelter Tinted Moisturizer SPF 18      More Moisturizer
#
#                                                     UserRating  \
# Product
# 100% Pure Aqua Boost Hydrating Mask                  10.000000
# 100% Pure Argan Oil Hydration Facial Moisturize...    8.000000
# 3LAB "M" Cream                                        9.333333
# 3LAB Shine Stop Moisturizer                           2.000000
# 40 Carrots Carrot and C Vitamin Serum                 6.000000
# ...                                                        ...
# iS Clinical Firming Complex                           8.000000
# iS Clinical Youth Complex                             4.000000
# j.Sabatelli Cosmetics j.Sabatelli Brazil Firmin...   10.000000
# mark For Goodness Face Antioxidant Skin Moistur...    9.500000
# the Balm BalmShelter Tinted Moisturizer SPF 18        9.888889
#
#                                                                                           ReviewText2  \
# Product
# 100% Pure Aqua Boost Hydrating Mask                 kind face mask cream freak test lot different ...
# 100% Pure Argan Oil Hydration Facial Moisturize...  pure argan oil hydration facial moisturizer sp...
# 3LAB "M" Cream                                      cream luxurious really make improvement skin e...
# 3LAB Shine Stop Moisturizer                         think would help oily skin expensive didnt say...
# 40 Carrots Carrot and C Vitamin Serum               love carrots serum leave skin feel silky prote...
# ...                                                                                               ...
# iS Clinical Firming Complex                         clinical products recommend beauty mag editor ...
# iS Clinical Youth Complex                           use power rich dermalogica couple years want t...
# j.Sabatelli Cosmetics j.Sabatelli Brazil Firmin...  never really healthy glow skin use along sabat...
# mark For Goodness Face Antioxidant Skin Moistur...  good moisturizer make skin really soft plus sp...
# the Balm BalmShelter Tinted Moisturizer SPF 18      tint moisturizers general arent enough coverag...
#
#                                                                                                 Tags2  \
# Product
# 100% Pure Aqua Boost Hydrating Mask                       hydrate different winter smooth since range
# 100% Pure Argan Oil Hydration Facial Moisturize...  moisturizer watery thick thailand temperature ...
# 3LAB "M" Cream                                            really wasnt notice leave cream without ive
# 3LAB Shine Stop Moisturizer                                  would without waste think products money
# 40 Carrots Carrot and C Vitamin Serum                           start serum product years weeks tight
# ...                                                                                               ...
# iS Clinical Firming Complex                             products think serums recommend potion please
# iS Clinical Youth Complex                                     power spend youth years wouldnt without
# j.Sabatelli Cosmetics j.Sabatelli Brazil Firmin...    sabatelli really radiant products never healthy
# mark For Goodness Face Antioxidant Skin Moistur...   moisturizer thing really package great dispenser
# the Balm BalmShelter Tinted Moisturizer SPF 18       product moisturizer coverage review really leave
#
#                                                                                           UserInput
# Product
# 100% Pure Aqua Boost Hydrating Mask                 power, healthy, coverage, radiant, great, youth
# 100% Pure Argan Oil Hydration Facial Moisturize...  power, healthy, coverage, radiant, great, youth
# 3LAB "M" Cream                                      power, healthy, coverage, radiant, great, youth
# 3LAB Shine Stop Moisturizer                         power, healthy, coverage, radiant, great, youth
# 40 Carrots Carrot and C Vitamin Serum               power, healthy, coverage, radiant, great, youth
# ...                                                                                             ...
# iS Clinical Firming Complex                         power, healthy, coverage, radiant, great, youth
# iS Clinical Youth Complex                           power, healthy, coverage, radiant, great, youth
# j.Sabatelli Cosmetics j.Sabatelli Brazil Firmin...  power, healthy, coverage, radiant, great, youth
# mark For Goodness Face Antioxidant Skin Moistur...  power, healthy, coverage, radiant, great, youth
# the Balm BalmShelter Tinted Moisturizer SPF 18      power, healthy, coverage, radiant, great, youth
#
# [1276 rows x 5 columns]

# %%
# Out:
# /Users/jessicapmouras/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/jessicapmouras/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#                                                             Category  \
# Product
# 100% Pure Aqua Boost Hydrating Mask                 More Moisturizer
# 100% Pure Argan Oil Hydration Facial Moisturize...  More Moisturizer
# 3LAB "M" Cream                                      More Moisturizer
# 3LAB Shine Stop Moisturizer                         More Moisturizer
# 40 Carrots Carrot and C Vitamin Serum               More Moisturizer
# ...                                                              ...
# iS Clinical Firming Complex                         More Moisturizer
# iS Clinical Youth Complex                           More Moisturizer
# j.Sabatelli Cosmetics j.Sabatelli Brazil Firmin...  More Moisturizer
# mark For Goodness Face Antioxidant Skin Moistur...  More Moisturizer
# the Balm BalmShelter Tinted Moisturizer SPF 18      More Moisturizer
#
#                                                     UserRating  \
# Product
# 100% Pure Aqua Boost Hydrating Mask                  10.000000
# 100% Pure Argan Oil Hydration Facial Moisturize...    8.000000
# 3LAB "M" Cream                                        9.333333
# 3LAB Shine Stop Moisturizer                           2.000000
# 40 Carrots Carrot and C Vitamin Serum                 6.000000
# ...                                                        ...
# iS Clinical Firming Complex                           8.000000
# iS Clinical Youth Complex                             4.000000
# j.Sabatelli Cosmetics j.Sabatelli Brazil Firmin...   10.000000
# mark For Goodness Face Antioxidant Skin Moistur...    9.500000
# the Balm BalmShelter Tinted Moisturizer SPF 18        9.888889
#
#                                                                                           ReviewText2  \
# Product
# 100% Pure Aqua Boost Hydrating Mask                 kind face mask cream freak test lot different ...
# 100% Pure Argan Oil Hydration Facial Moisturize...  pure argan oil hydration facial moisturizer sp...
# 3LAB "M" Cream                                      cream luxurious really make improvement skin e...
# 3LAB Shine Stop Moisturizer                         think would help oily skin expensive didnt say...
# 40 Carrots Carrot and C Vitamin Serum               love carrots serum leave skin feel silky prote...
# ...                                                                                               ...
# iS Clinical Firming Complex                         clinical products recommend beauty mag editor ...
# iS Clinical Youth Complex                           use power rich dermalogica couple years want t...
# j.Sabatelli Cosmetics j.Sabatelli Brazil Firmin...  never really healthy glow skin use along sabat...
# mark For Goodness Face Antioxidant Skin Moistur...  good moisturizer make skin really soft plus sp...
# the Balm BalmShelter Tinted Moisturizer SPF 18      tint moisturizers general arent enough coverag...
#
#                                                                                                 Tags2  \
# Product
# 100% Pure Aqua Boost Hydrating Mask                       hydrate different winter smooth since range
# 100% Pure Argan Oil Hydration Facial Moisturize...  moisturizer watery thick thailand temperature ...
# 3LAB "M" Cream                                            really wasnt notice leave cream without ive
# 3LAB Shine Stop Moisturizer                                  would without waste think products money
# 40 Carrots Carrot and C Vitamin Serum                           start serum product years weeks tight
# ...                                                                                               ...
# iS Clinical Firming Complex                             products think serums recommend potion please
# iS Clinical Youth Complex                                     power spend youth years wouldnt without
# j.Sabatelli Cosmetics j.Sabatelli Brazil Firmin...    sabatelli really radiant products never healthy
# mark For Goodness Face Antioxidant Skin Moistur...   moisturizer thing really package great dispenser
# the Balm BalmShelter Tinted Moisturizer SPF 18       product moisturizer coverage review really leave
#
#                                                                                           UserInput
# Product
# 100% Pure Aqua Boost Hydrating Mask                 power, healthy, coverage, radiant, great, youth
# 100% Pure Argan Oil Hydration Facial Moisturize...  power, healthy, coverage, radiant, great, youth
# 3LAB "M" Cream                                      power, healthy, coverage, radiant, great, youth
# 3LAB Shine Stop Moisturizer                         power, healthy, coverage, radiant, great, youth
# 40 Carrots Carrot and C Vitamin Serum               power, healthy, coverage, radiant, great, youth
# ...                                                                                             ...
# iS Clinical Firming Complex                         power, healthy, coverage, radiant, great, youth
# iS Clinical Youth Complex                           power, healthy, coverage, radiant, great, youth
# j.Sabatelli Cosmetics j.Sabatelli Brazil Firmin...  power, healthy, coverage, radiant, great, youth
# mark For Goodness Face Antioxidant Skin Moistur...  power, healthy, coverage, radiant, great, youth
# the Balm BalmShelter Tinted Moisturizer SPF 18      power, healthy, coverage, radiant, great, youth
#
# [1276 rows x 5 columns]

# %%
def jw(df):
    jarowinkler = JaroWinkler()
    df["jarowinkler_sim"] = [jarowinkler.similarity(i,j) for i,j in zip(df["Tags2"],df["UserInput"])]
    df.sort_values(by=['jarowinkler_sim'], inplace=True, ascending=False)
    final = df.drop(['Category','ReviewText2', 'Tags2'], axis=1).iloc[:5,:]
    
    
    return final

# %%
jw(user_input(select_category(testingdf,'More Cleanser'), 'clean, normal, breakout, sensitive, strong, shower'))
# Out:
# /Users/jessicapmouras/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/jessicapmouras/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/jessicapmouras/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/jessicapmouras/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                                                    UserRating  \
# Product
# Kate Somerville Purifying Exfoliating Cleanser       8.250000
# Avon liiv botanicals Rejuvenating Facial Cleanser    6.750000
# HydroPeptide Anti-Wrinkle Exfoliating Cleanser       7.200000
# Clarins Cleansing Milk With Alpine Herbs             7.200000
# Pond's Luminous Clean Cream Cleanser                 9.666667
#
#                                                                                            UserInput  \
# Product
# Kate Somerville Purifying Exfoliating Cleanser     clean, normal, breakout, sensitive, strong, sh...
# Avon liiv botanicals Rejuvenating Facial Cleanser  clean, normal, breakout, sensitive, strong, sh...
# HydroPeptide Anti-Wrinkle Exfoliating Cleanser     clean, normal, breakout, sensitive, strong, sh...
# Clarins Cleansing Milk With Alpine Herbs           clean, normal, breakout, sensitive, strong, sh...
# Pond's Luminous Clean Cream Cleanser               clean, normal, breakout, sensitive, strong, sh...
#
#                                                    jarowinkler_sim
# Product
# Kate Somerville Purifying Exfoliating Cleanser            0.769788
# Avon liiv botanicals Rejuvenating Facial Cleanser         0.766626
# HydroPeptide Anti-Wrinkle Exfoliating Cleanser            0.761071
# Clarins Cleansing Milk With Alpine Herbs                  0.747045
# Pond's Luminous Clean Cream Cleanser                      0.746327
